# %% [markdown]
# <a href="https://colab.research.google.com/github/Caosbot/Treinos_Python/blob/Machine_Learning/Desafio4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O programa roda em ambiente virtual de hospedagem local, possibilitando dentro da configuração utilizar minha GPU

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf

import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio


pio.renderers.default = "colab" #Para o Plotly aparecer no colab

# %% [markdown]
# ## Base de dados

# %%
base = pd.read_csv(r"F:\Cursos\DNC\Banco de dados\Desafio\MKT.csv")

# %%
base
# Out:
#      youtube  facebook  newspaper  sales
# 0      84.72     19.20      48.96  12.60
# 1     351.48     33.96      51.84  25.68
# 2     135.48     20.88      46.32  14.28
# 3     116.64      1.80      36.00  11.52
# 4     318.72     24.00       0.36  20.88
# ..       ...       ...        ...    ...
# 166    45.84      4.44      16.56   9.12
# 167   113.04      5.88       9.72  11.64
# 168   212.40     11.16       7.68  15.36
# 169   340.32     50.40      79.44  30.60
# 170   278.52     10.32      10.44  16.08
#
# [171 rows x 4 columns]

# %% [markdown]
# ### Analise dos Dados

# %%
base.columns
# Out:
# Index(['youtube', 'facebook', 'newspaper', 'sales'], dtype='object')

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   youtube    171 non-null    float64
#  1   facebook   171 non-null    float64
#  2   newspaper  171 non-null    float64
#  3   sales      171 non-null    float64
# dtypes: float64(4)
# memory usage: 5.5 KB

# %%
base.describe()
# Out:
#           youtube    facebook   newspaper       sales
# count  171.000000  171.000000  171.000000  171.000000
# mean   178.021053   27.671579   35.240000   16.922807
# std    102.449597   17.913532   24.902918    6.314608
# min      0.840000    0.000000    0.360000    1.920000
# 25%     91.080000   11.700000   13.740000   12.540000
# 50%    179.760000   26.760000   31.080000   15.480000
# 75%    262.980000   43.680000   50.880000   20.820000
# max    355.680000   59.520000  121.080000   32.400000

# %% [markdown]
# O dataframe contem 171 linhas e 4 colunas.
#
# A variação de investimento nas midias youtube, facebook e newspaper, resultam em uma quantidade de vendas.

# %% [markdown]
# ### Gráficos dos dados

# %% [markdown]
# #### Plotly Sales

# %%
fig = px.box(base, x="sales")
fig.update_traces(line_color="blue")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 75%
# Aqui para observar os investimentos que resultaram nas maiores porções de vendas.

# %%
base[(base["sales"]>=base["sales"].quantile(0.75))].sort_values(ascending=False, by='sales').reset_index()
# Out:
#     index  youtube  facebook  newspaper  sales
# 0     146   332.28     58.68      50.16  32.40
# 1     154   345.12     51.60      86.16  31.44
# 2     169   340.32     50.40      79.44  30.60
# 3       7   320.28     52.56       6.00  30.48
# 4     118   291.84     58.80      53.16  30.48
# 5      69   347.64     50.76      61.44  30.48
# 6      99   264.36     58.80       3.84  29.64
# 7      32   313.56     51.24      65.64  29.04
# 8      29   252.96     59.52      45.24  28.56
# 9      72   355.68     43.56     121.08  28.56
# 10     26   238.68     59.28      72.00  28.44
# 11     18   287.88     49.80      22.20  27.84
# 12    156   246.00     54.12      23.52  27.12
# 13     23   259.68     50.04      47.52  27.12
# 14     40   260.16     52.68      32.64  26.76
# 15     64   301.08     43.80      86.76  26.64
# 16     82   290.04     45.60      27.84  26.16
# 17     55   256.20     51.60      40.56  26.04
# 18     10   273.60     45.24      38.40  25.80
# ...

# %% [markdown]
# #### Plotly Youtube

# %%
fig = px.box(base, x="youtube")
fig.update_traces(line_color="red")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 75%
# Aqui para observar as maiores investidas no Youtube e retorno em vendas

# %%
base[(base["youtube"]>=base["youtube"].quantile(0.75))].sort_values(ascending=False, by='youtube').reset_index()
# Out:
#     index  youtube  facebook  newspaper  sales
# 0      72   355.68     43.56     121.08  28.56
# 1      13   352.32     33.24       2.16  24.84
# 2       1   351.48     33.96      51.84  25.68
# 3       6   348.84      4.92      10.20  15.36
# 4      69   347.64     50.76      61.44  30.48
# 5     154   345.12     51.60      86.16  31.44
# 6     159   343.20     16.68       4.44  19.08
# 7     140   341.16     12.72       7.68  18.00
# 8     169   340.32     50.40      79.44  30.60
# 9     121   336.84     16.68      44.40  19.32
# 10     73   336.24     12.12      25.68  17.76
# 11    146   332.28     58.68      50.16  32.40
# 12    149   332.04      2.76      28.44  14.16
# 13    108   328.44     34.68      71.64  24.96
# 14      7   320.28     52.56       6.00  30.48
# 15      4   318.72     24.00       0.36  20.88
# 16    102   318.24      3.48      51.60  15.24
# 17     25   315.24     34.56      19.08  24.24
# 18     32   313.56     51.24      65.64  29.04
# ...

# %% [markdown]
# #### Plotly Facebook

# %%
fig = px.box(base, x="facebook")
fig.update_traces(line_color="green")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 75%
# Aqui para observar as maiores investidas no Facebook e retorno em vendas

# %%
base[(base["facebook"]>=base["facebook"].quantile(0.75))].sort_values(ascending=False, by='facebook').reset_index()
# Out:
#     index  youtube  facebook  newspaper  sales
# 0      29   252.96     59.52      45.24  28.56
# 1      26   238.68     59.28      72.00  28.44
# 2       8    89.64     59.28      54.84  17.64
# 3     118   291.84     58.80      53.16  30.48
# 4      99   264.36     58.80       3.84  29.64
# 5     146   332.28     58.68      50.16  32.40
# 6      60   131.76     57.36      61.68  20.04
# 7     106    57.96     56.40      10.20  13.92
# 8      85    93.84     56.16      41.40  17.52
# 9      76   165.48     55.68      70.80  23.04
# 10     24   219.12     55.44      70.44  25.44
# 11    156   246.00     54.12      23.52  27.12
# 12     54    82.08     53.40      42.72  16.32
# 13    110   221.88     52.68       2.04  24.84
# 14     40   260.16     52.68      32.64  26.76
# 15      7   320.28     52.56       6.00  30.48
# 16     46    20.28     52.44     107.28  10.44
# 17    127   112.68     52.20      60.60  18.36
# 18    154   345.12     51.60      86.16  31.44
# ...

# %% [markdown]
# #### Plotly Newspapper
# Possui outlayer de valor 121

# %%
fig = px.box(base, x="newspaper")
fig.update_traces(line_color="yellow")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 75%
# Aqui para observar as maiores investidas no newspaper e retorno em vendas

# %%
base[(base["newspaper"]>=base["newspaper"].quantile(0.75))].sort_values(ascending=False, by='newspaper').reset_index()
# Out:
#     index  youtube  facebook  newspaper  sales
# 0      72   355.68     43.56     121.08  28.56
# 1      46    20.28     52.44     107.28  10.44
# 2     136   281.40      4.08     101.76  14.28
# 3      89   150.84     44.28      95.04  19.08
# 4     112   232.44     42.48      90.72  23.04
# 5      95   275.40     38.76      89.04  23.64
# 6      59   105.96     30.60      88.08  15.48
# 7      64   301.08     43.80      86.76  26.64
# 8     154   345.12     51.60      86.16  31.44
# 9     169   340.32     50.40      79.44  30.60
# 10     56   231.84     22.08      78.84  18.24
# 11    105    44.28     46.32      78.72  12.96
# 12     58   132.84     48.72      75.84  19.20
# 13     26   238.68     59.28      72.00  28.44
# 14    108   328.44     34.68      71.64  24.96
# 15     63   261.24     40.20      70.80  23.28
# 16     76   165.48     55.68      70.80  23.04
# 17     24   219.12     55.44      70.44  25.44
# 18    139   258.48     28.32      69.12  20.52
# ...

# %% [markdown]
# ## Correlação

# %%
base.corr()
# Out:
#             youtube  facebook  newspaper     sales
# youtube    1.000000  0.086538   0.110759  0.782030
# facebook   0.086538  1.000000   0.293425  0.602918
# newspaper  0.110759  0.293425   1.000000  0.254987
# sales      0.782030  0.602918   0.254987  1.000000

# %%
sns.heatmap(base.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Visualização Youtube com sales

# %%
base['youtube'].quantile(0.75)
# Out:
# 262.98

# %% [markdown]
# **Maior retorno em sales**

# %%
youtube_sales = base.groupby("youtube")['sales'].agg("mean").sort_values(ascending=False).reset_index().query("youtube > youtube.quantile(0.75)")
youtube_sales
# Out:
#      youtube  sales
# 0     332.28  32.40
# 1     345.12  31.44
# 2     340.32  30.60
# 3     347.64  30.48
# 4     291.84  30.48
# 5     320.28  30.48
# 6     264.36  29.64
# 7     313.56  29.04
# 8     355.68  28.56
# 11    287.88  27.84
# 15    301.08  26.64
# 16    290.04  26.16
# 18    273.60  25.80
# 19    351.48  25.68
# 21    328.44  24.96
# 22    285.84  24.84
# 23    352.32  24.84
# 24    298.08  24.24
# 25    315.24  24.24
# 26    264.60  24.12
# 27    306.48  23.76
# 28    275.40  23.64
# 35    284.88  22.68
# 41    304.56  21.12
# 42    318.72  20.88
# 50    336.84  19.32
# 53    343.20  19.08
# 55    287.16  18.84
# 61    341.16  18.00
# 65    272.64  17.76
# 66    336.24  17.76
# 78    278.52  16.08
# 80    270.96  16.08
# 83    288.12  15.84
# 87    348.84  15.36
# 88    318.24  15.24
# 91    287.76  14.76
# 96    281.40  14.28
# 99    332.04  14.16
# 103   268.80  13.92
# 104   266.88  13.92

# %%
px.bar(youtube_sales, x= "youtube", y = "sales", color_discrete_sequence=["red"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Visualização Facebook com sales

# %%
base['facebook'].quantile(0.75)
# Out:
# 43.68

# %% [markdown]
# **Maior retorno em sales**

# %%
facebook_sales = base.groupby("facebook")['sales'].agg("mean").sort_values(ascending=False).reset_index().query("facebook > facebook.quantile(0.75)")
facebook_sales
# Out:
#      facebook  sales
# 0       58.68  32.40
# 1       50.76  30.48
# 2       52.56  30.48
# 3       58.80  30.06
# 4       51.24  29.04
# 5       51.60  28.74
# 6       59.52  28.56
# 8       49.80  27.84
# 9       54.12  27.12
# 10      50.40  27.06
# 11      43.80  26.64
# 12      45.60  26.16
# 13      52.68  25.80
# 14      45.24  25.80
# 16      55.44  25.44
# 23      50.04  23.88
# 28      55.68  23.04
# 29      59.28  23.04
# 30      47.64  22.80
# 33      44.16  21.60
# 34      51.36  21.60
# 42      57.36  20.04
# 46      48.72  19.20
# 53      52.20  18.36
# 61      56.16  17.52
# 67      53.40  16.32
# 92      56.40  13.92
# 93      44.28  13.92
# 102     48.36  13.08
# 103     46.32  12.96
# 104     49.32  12.96
# 120     46.80  11.40
# 125     52.44  10.44
# 131     45.12   9.60
# 138     46.68   7.92
# 144     47.52   1.92

# %%
px.bar(facebook_sales, x= "facebook", y = "sales", color_discrete_sequence=["blue"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Visualização Newspaper com sales

# %%
base['newspaper'].quantile(0.75)
# Out:
# 50.879999999999995

# %% [markdown]
# **Maior retorno em sales**

# %%
newspaper_sales =  base.groupby("newspaper")['sales'].agg("mean").sort_values(ascending=False).reset_index().query("newspaper > newspaper.quantile(0.75)")
newspaper_sales
# Out:
#      newspaper  sales
# 1        86.16  31.44
# 2        79.44  30.60
# 4        61.44  30.48
# 7        65.64  29.04
# 8       121.08  28.56
# 9        72.00  28.44
# 14       86.76  26.64
# 19       70.44  25.44
# 20       71.64  24.96
# 28       89.04  23.64
# 29       54.12  23.52
# 30       70.80  23.16
# 31       90.72  23.04
# 37       55.08  20.64
# 38       69.12  20.52
# 39       63.48  20.28
# 40       61.68  20.04
# 42       75.84  19.20
# 45       95.04  19.08
# 49       55.44  18.60
# 51       60.60  18.36
# 54       78.84  18.24
# 57       59.88  17.76
# 58       54.84  17.64
# 61       56.88  17.40
# 72       67.80  16.08
# 73       59.16  15.96
# 77       88.08  15.48
# 80       63.24  15.12
# 88      101.76  14.28
# 92       59.76  14.04
# 97       58.44  13.92
# 108      78.72  12.96
# 131     107.28  10.44
# 139      54.24   8.76
# 140      60.48   8.40
# 143      60.72   7.92

# %%
px.bar(newspaper_sales, x= "newspaper", y = "sales", color_discrete_sequence=["black"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Visualização duplas com vendas

# %%
base.groupby(['youtube', 'facebook'])['sales'].agg("mean").reset_index().query("sales > sales.quantile(0.75)").sort_values(ascending=False, by='sales').reset_index()
# Out:
#     index  youtube  facebook  sales
# 0     159   332.28     58.68  32.40
# 1     165   345.12     51.60  31.44
# 2     162   340.32     50.40  30.60
# 3     147   291.84     58.80  30.48
# 4     166   347.64     50.76  30.48
# 5     156   320.28     52.56  30.48
# 6     129   264.36     58.80  29.64
# 7     152   313.56     51.24  29.04
# 8     170   355.68     43.56  28.56
# 9     120   252.96     59.52  28.56
# 10    111   238.68     59.28  28.44
# 11    144   287.88     49.80  27.84
# 12    124   259.68     50.04  27.12
# 13    115   246.00     54.12  27.12
# 14    125   260.16     52.68  26.76
# 15    149   301.08     43.80  26.64
# 16    146   290.04     45.60  26.16
# 17    122   256.20     51.60  26.04
# 18    136   273.60     45.24  25.80
# 19    168   351.48     33.96  25.68
# 20    100   219.12     55.44  25.44
# 21    157   328.44     34.68  24.96
# 22    102   221.88     52.68  24.84
# 23    141   285.84     41.16  24.84
# 24    169   352.32     33.24  24.84
# ...

# %%
base.groupby(['facebook', 'newspaper'])['sales'].agg("mean").reset_index().query("sales > sales.quantile(0.75)").sort_values(ascending=False, by='sales').reset_index()
# Out:
#     index  facebook  newspaper  sales
# 0     165     58.68      50.16  32.40
# 1     152     51.60      86.16  31.44
# 2     147     50.40      79.44  30.60
# 3     167     58.80      53.16  30.48
# 4     155     52.56       6.00  30.48
# 5     148     50.76      61.44  30.48
# 6     166     58.80       3.84  29.64
# 7     149     51.24      65.64  29.04
# 8     170     59.52      45.24  28.56
# 9     127     43.56     121.08  28.56
# 10    169     59.28      72.00  28.44
# 11    143     49.80      22.20  27.84
# 12    159     54.12      23.52  27.12
# 13    144     50.04      47.52  27.12
# 14    157     52.68      32.64  26.76
# 15    128     43.80      86.76  26.64
# 16    134     45.60      27.84  26.16
# 17    151     51.60      40.56  26.04
# 18    133     45.24      38.40  25.80
# 19    104     33.96      51.84  25.68
# 20    160     55.44      70.44  25.44
# 21    108     34.68      71.64  24.96
# 22    121     41.16       6.36  24.84
# 23    156     52.68       2.04  24.84
# ...

# %%
base.groupby(['youtube', 'newspaper'])['sales'].agg("mean").reset_index().query("sales > sales.quantile(0.75)").sort_values(ascending=False, by='sales').reset_index()
# Out:
#     index  youtube  newspaper  sales
# 0     159   332.28      50.16  32.40
# 1     165   345.12      86.16  31.44
# 2     162   340.32      79.44  30.60
# 3     147   291.84      53.16  30.48
# 4     166   347.64      61.44  30.48
# 5     156   320.28       6.00  30.48
# 6     129   264.36       3.84  29.64
# 7     152   313.56      65.64  29.04
# 8     170   355.68     121.08  28.56
# 9     120   252.96      45.24  28.56
# 10    111   238.68      72.00  28.44
# 11    144   287.88      22.20  27.84
# 12    124   259.68      47.52  27.12
# 13    115   246.00      23.52  27.12
# 14    125   260.16      32.64  26.76
# 15    149   301.08      86.76  26.64
# 16    146   290.04      27.84  26.16
# 17    122   256.20      40.56  26.04
# 18    136   273.60      38.40  25.80
# 19    168   351.48      51.84  25.68
# 20    100   219.12      70.44  25.44
# 21    157   328.44      71.64  24.96
# 22    101   221.88       2.04  24.84
# 23    141   285.84       6.36  24.84
# ...

# %% [markdown]
# ## Preparo para Treino

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor

# %% [markdown]
# ### Ajustando para treino

# %%
base_col = base.columns
base_col = base_col.drop('sales')
base_col
# Out:
# Index(['youtube', 'facebook', 'newspaper'], dtype='object')

# %%
X = base[base_col]

Y = base["sales"]

# %%
X_train, X_test, Y_train, Y_test  = train_test_split(X,Y, train_size = 0.7, test_size=0.3,random_state = 42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (119, 3)
# (52, 3)
# (119,)
# (52,)

# %% [markdown]
# ## Treino

# %% [markdown]
# ### Tecnica 1 . Regressão Linear

# %%
linearReg = LinearRegression()

# %%
linearReg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
pred_linear = linearReg.predict(X_test)

# %%
r2linear = r2_score(Y_test, pred_linear)

# %%
MSELinear = mean_squared_error(Y_test, pred_linear) #Comparando os valores

# %%
print(f"MSE: {MSELinear}")
print(f"RMSE: {np.sqrt(MSELinear)}") #Erro em torno de até
print (f"r_quadrado: {r2linear*100:.2f}%")
# Out:
# MSE: 4.699445585122348
# RMSE: 2.1678204688401546
# r_quadrado: 88.24%

# %% [markdown]
# ### Tecnica 2. SVR

# %%
regSVR = SVR().fit(X_train,Y_train) #Treinando o modelo
pred_SVR = regSVR.predict(X_test) #Testando o modelo

# %%
MSESVR = mean_squared_error(Y_test, pred_SVR)

# %%
r2SVR = r2_score(Y_test, pred_SVR)

# %%
print(f"MSE: {MSESVR}")
print(f"RMSE: {np.sqrt(MSESVR)}") #Erro em torno de até
print (f"r_quadrado: {r2SVR*100:.2f}%")
# Out:
# MSE: 9.30448670066444
# RMSE: 3.0503256712463407
# r_quadrado: 76.72%

# %% [markdown]
# ### Tecnica 3 Decision Tree Regression (XGBoost)

# %%
regXGB = XGBRegressor().fit(X_train,Y_train) #Treinando o modelo
pred_XGB = regXGB.predict(X_test) #Testando o modelo

# %%
MSEXGB =mean_squared_error(Y_test, pred_XGB)

# %%
r2XGB = r2_score(Y_test, pred_XGB)

# %%
print(f"MSE: {MSEXGB}")
print(f"RMSE: {np.sqrt(MSEXGB)}") #Erro em torno de até
print (f"r_quadrado: {r2XGB*100:.2f}%")
# Out:
# MSE: 1.6327100952934968
# RMSE: 1.2777754479146548
# r_quadrado: 95.92%

# %% [markdown]
# ### Gráficos das previsões

# %% [markdown]
# #### Regressão Linear

# %%
c = [i for i in range(1,(Y_test.size+1),1)]
fig = plt.figure(figsize=(12, 8))
plt.plot(c, Y_test, color="blue", label="Valores Reais")
plt.plot(c, pred_linear, color="red", label="Valores Previstos")
plt.xlabel("Regressão Linear")
plt.ylabel("Vendas")
plt.legend()
plt.show();

# %% [markdown]
# #### SVR

# %%
c = [i for i in range(1,(Y_test.size+1),1)]
fig = plt.figure(figsize=(12, 8))
plt.plot(c, Y_test, color="blue", label="Valores Reais")
plt.plot(c, pred_SVR, color="red", label="Valores Previstos")
plt.xlabel("SVR")
plt.ylabel("Vendas")
plt.legend()
plt.show();

# %% [markdown]
# #### Decision Tree Regression (XGBoost)

# %%
c = [i for i in range(1,(Y_test.size+1),1)]
fig = plt.figure(figsize=(12, 8))
plt.plot(c, Y_test, color="blue", label="Valores Reais")
plt.plot(c, pred_XGB, color="red", label="Valores Previstos")
plt.xlabel("Decision Tree Regression (XGBoost)")
plt.ylabel("Vendas")
plt.legend()
plt.show();

# %% [markdown]
# #Proposta de investimento

# %% [markdown]
# ## Formatando Dataframe

# %%
base_col
# Out:
# Index(['youtube', 'facebook', 'newspaper'], dtype='object')

# %%
#Proposta
def prop(youtube=332., facebook = 58.,newspaper = 32. ):
  '''
  Colocar a proposta de investimento:
  Primeiro valor float para 'Youtube'
  Segundo calor float para 'facebook'
  Terceiro valor float para 'newspaper'
  '''
  youtube = youtube
  facebook = facebook
  newspaper = newspaper

  dados = [[youtube,facebook,newspaper]]
  entrada = base_col.copy()

  df = pd.DataFrame(dados, columns=entrada)
  return df

# %% [markdown]
# ## Proposta teste
#
#
# ```
# df = prop(350.,60.,35.)
# ```

# %%
df = prop(350.,60.,10.)
df
# Out:
#    youtube  facebook  newspaper
# 0    350.0      60.0       10.0

# %% [markdown]
# ## Recomendado: Decision Tree Regression (XGBoost)

# %%
pred_XGB = regXGB.predict(df)[0]
print(f"Previsão de vendas: {pred_XGB:.2f}")
# Out:
# Previsão de vendas: 32.31

# %% [markdown]
# ## Previsão Regressão Linear

# %%
pred_linear= linearReg.predict(df)[0]
print(f"Previsão de vendas: {pred_linear:.2f}")
# Out:
# Previsão de vendas: 30.77

# %% [markdown]
# ## Previsão SVR

# %%
pred_SVR = regSVR.predict(df)[0] #Testando o modelo
print(f"Previsão de vendas: {pred_SVR:.2f}")
# Out:
# Previsão de vendas: 22.45
