# %% [markdown]
# <a href="https://colab.research.google.com/github/Caosbot/Treinos_Python/blob/Machine_Learning/yoloSeg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prev com Yolo

# %%
from ultralytics import YOLO
import os
from random import randint
import cv2
import matplotlib.pyplot as plt
import torch
import numpy as np

# %%
def mostrar(imagem,title):
  fig = plt.gcf()
  fig.set_size_inches(20,10)
  plt.imshow(imagem, cmap='gray')
  plt.title(title)
  #plt.axis('off')
  plt.show()

# %% [markdown]
# ## Caminhos

# %%
#Caminho da pasta inicial
path= 'C:/Malaria'

# %%
path_dataset = path+'/Tudo/dataset'
path_dataset
# Out:
# 'C:/Malaria/Tudo/dataset'

# %%
path_image_test = path_dataset+'/test/images'
path_image_test
# Out:
# 'C:/Malaria/Tudo/dataset/test/images'

# %% [markdown]
# ## Exemplo

# %%
best = r'C:\Malaria\runs\detect\All_Data\weights\best.pt'

# %%
caminhos_pasta = [os.path.join(path_image_test, f) for f in os.listdir(path_image_test)]
nums_pasta = randint(0, len(caminhos_pasta) - 1)
print(f'Numero aleatorio: {nums_pasta}, Qtd: {len(caminhos_pasta)}')
pasta = caminhos_pasta[nums_pasta]
print(f'Nome: {pasta}')
# Out:
# Numero aleatorio: 60, Qtd: 62
# Nome: C:/Malaria/Tudo/dataset/test/images\TF98_CT12

# %%
caminhos_arquivo = [os.path.join(pasta, f) for f in os.listdir(pasta)]
nums_arquivo = randint(0, len(caminhos_arquivo) - 1)
print(f'Numero aleatorio: {nums_arquivo}, Qtd: {len(caminhos_arquivo)}')
arquivo = caminhos_arquivo[nums_arquivo]
print(f'Nome: {arquivo}')
# Out:
# Numero aleatorio: 8, Qtd: 10
# Nome: C:/Malaria/Tudo/dataset/test/images\TF98_CT12\20170829_201732.jpg

# %%
image_teste = cv2.imread(arquivo)
image_bound = image_teste.copy()

# %%
mostrar(image_teste,'Exemplo')

# %% [markdown]
# ## Corte

# %%
# Define cores para cada tipo de célula
cores = {
    "white_cell": (255, 0, 0),  # Vermelho
    "malaria": (0, 255, 0),  # Verde
}

# Define a espessura da linha
espessura_linha = 1

# %%
# Define as listas de células e suas quantidades
white_cell=[]
malaria =[]
cell_types = ["white_cell","malaria"]
cell_counts = []
count=0

# Carrega o modelo e executa a inferência
model1 = YOLO(best)  # pretrained YOLOv8n model
results1 = model1([image_teste])  # Guarda em result1 objects Comando tirado(, imgsz=640)
##########################################
boxes = results1[0].boxes.xywh.tolist()
##########################################
# Processa os resultados
boxes_filtered = [box for result in results1 for box in result.boxes if int(box.cls[0].item()) != 3]

for box in boxes_filtered:
  if int(box.cls[0].item()) == 0:
    white_cell.append(box[0].xyxy[0].tolist())
  elif int(box.cls[0].item()) == 1:
     malaria.append(box[0].xyxy[0].tolist())
  # elif int(box.cls[0].item()) == 2:
  #   leucocito.append(box[0].xyxy[0].tolist())

# Preenche a lista de quantidades
for cell_type in cell_types:
  # Verifica se a variável associada ao tipo de célula existe
  if locals()[cell_type]:  # Acessa variáveis dinamicamente
    cell_counts.append(len(locals()[cell_type]))
  else:
    cell_counts.append(0)  # Quantidade zero se a lista estiver vazia

# Combina tipos de células e quantidades em uma lista
cell_data = list(zip(cell_types, cell_counts))

# Exibe os resultados
total = 0
for cell_type, count in cell_data:
  total+=count
  print(f"Quantidade de {cell_type}: {count}")

  # print(f"Conteúdo de {cell_type}:")
  # for item in locals()[cell_type]:
  #   print(item)
print(f'Total: {total}')
# Out:
# 0: 640x640 26 white_cells, 214 malarias, 8.0ms
# Speed: 5.0ms preprocess, 8.0ms inference, 2867.1ms postprocess per image at shape (1, 3, 640, 640)
# Quantidade de white_cell: 26
# Quantidade de malaria: 214
# Total: 240

# %%
image_teste = cv2.imread(arquivo)
image_bound = image_teste.copy()
images_yolo=[]
qtd=0
nt_malaria=0
nt_white_cell=0
# Loop para recortar e plotar células individualmente
for cell_type, count in cell_data:
  if count > 0:  # Processa apenas células com detecções

    # Cria uma subpasta para cada tipo de célula
    #os.makedirs(f"{crop_data_path}/{cell_type}", exist_ok=True)  # Cria pasta se não existir
    for i, box in enumerate(locals()[cell_type]):
      qtd+=1

      x1, y1, x2, y2 = box
      # # Recorta o objeto usando as coordenadas da caixa delimitadora
      crop_object = image_teste[int(y1):int(y2), int(x1):int(x2)]

      # # Redimensionamento da imagem recortada
      crop_object = cv2.resize(crop_object, dsize=(50, 50))
      # Salva o objeto recortado
      #cv2.imwrite(f"{crop_data_path}/{cell_type}/{cell_type}{i + 1}.jpg", ultralytics_crop_object)
      images_yolo.append(np.array(crop_object))

      # Converte a caixa para valores inteiros
      x1, y1, x2, y2 = int(box[0]), int(box[1]), int(box[2]), int(box[3])

      if cell_type=='white_cell':
        nt_white_cell+=1
        cv2.putText(image_bound, str(nt_white_cell), (x1, y1), 0, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
      else:
        nt_malaria+=1
        cv2.putText(image_bound, str(nt_malaria), (x1, y1), 0, 0.5, (0, 0, 255), 1, cv2.LINE_AA)


      # Desenha a bounding box na imagem original
      cv2.rectangle(image_bound, (x1, y1), (x2, y2), cores[cell_type], espessura_linha)



      # # Plota o objeto recortado
      #plt.figure(figsize=(8, 6))  # Define o tamanho da figura (opcional)
      #plt.imshow(ultralytics_crop_object)
      #plt.title(f"Célula {cell_type} {i + 1}")  # Adiciona título
      #plt.axis('off')  # Desliga rótulos e marcas do eixo
      #plt.show()  # Exibe o gráfico
print(f'nt_white_cell: {nt_white_cell} | nt_malaria: {nt_malaria}')
mostrar(image_bound, f"Red Box- White Cell {nt_white_cell}, Green Box- Malaria {nt_malaria} | Total:{qtd}")

#cv2.imwrite(f"{crop_data_path}/{cell_type}/bounding.jpg", manipulado)
# Out:
# nt_white_cell: 26 | nt_malaria: 214

# %% [markdown]
# # CNN

# %% [markdown]
# ## Bibliotecas iniciais

# %%
# Importar alguns dos módulos necessários
import os
#import zipfile
import cv2
from PIL import Image
import math
import matplotlib.pyplot as plt
from datetime import datetime
import random
import time

# %%
# Obter data e hora atuais
data_hora_atual = datetime.now()

# Formatar a data e hora
print(data_hora_atual.strftime("%H:%M:%S %d-%m-%Y"))
# Out:
# 09:48:47 18-06-2024

# %% [markdown]
# ## Dataset

# %%
main = r'F:\Dataset\Crop'
vivax_path = main+'\Vivax'
falciparum_path = main+'\Falciparum'
white_path = main+'\WhiteBloodCells'

# %%
vivax_names = [os.path.join(vivax_path,f) for f in os.listdir(vivax_path)]
falciparum_names = [os.path.join(falciparum_path,f) for f in os.listdir(falciparum_path)]
white_names = [os.path.join(white_path,f) for f in os.listdir(white_path)]

# %%
vivax_qtd =  len(vivax_names)
falciparum_qtd = len(falciparum_names)
white_qtd = len(white_names)
#vivax_total = vivax_train_qtd+vivax_valid_qtd+vivax_test_qtd
print(f'vivax_qtd: {vivax_qtd}\nfalciparum_qtd: {falciparum_qtd}\nwhite_names: {white_qtd}')
# Out:
# vivax_qtd: 25706
# falciparum_qtd: 84509
# white_names: 35449

# %%
def Dividir_data (valor_total):
  para_treino = 70
  para_teste = 20
  para_validacao = 10

  para_treinor = math.floor(valor_total * (para_treino / 100))
  para_tester = math.floor(valor_total * (para_teste / 100))
  para_validacaor = math.floor(valor_total * (para_validacao / 100))

  #para_treinor = valor_total * (para_treino / 100) - para_treinor
  #para_tester = valor_total * (para_teste / 100) - para_tester
  #para_validacaor = valor_total * (para_validacao / 100) - para_validacaor

  print(f"{para_treino}% de {valor_total} é {para_treinor:.0f}")
  print(f"{para_teste}% de {valor_total} é {para_tester:.0f}")
  print(f"{para_validacao}% de {valor_total} é {para_validacaor:.0f}")

# %%
print ('Vivax')
Dividir_data(vivax_qtd)
print ('\nFalciparum')
Dividir_data(falciparum_qtd)
print ('\nWhiteCell')
Dividir_data(white_qtd)
# Out:
# Vivax
# 70% de 25706 é 17994
# 20% de 25706 é 5141
# 10% de 25706 é 2570
#
# Falciparum
# 70% de 84509 é 59156
# 20% de 84509 é 16901
# 10% de 84509 é 8450
#
# WhiteCell
# 70% de 35449 é 24814
# 20% de 35449 é 7089
# 10% de 35449 é 3544

# %%
tamanho = 10000
falciparum_names_train = random.sample(falciparum_names, tamanho)
vivax_names_train = random.sample(vivax_names, tamanho)
white_names_train = random.sample(white_names, tamanho)
#falciparum_names_train = falciparum_names[:17994]
#vivax_names_train = vivax_names[:17994]
#white_names_train = white_names[:17994]
print(tamanho*3)
# Out:
# 30000

# %%
def mostrar(imagem,title):
  fig = plt.gcf()
  fig.set_size_inches(20,10)
  plt.imshow(imagem, cmap='gray')
  plt.title(title)
  #plt.axis('off')
  plt.show()

# %%
r =np.random.randint(0,len(vivax_names_train))
r
# Out:
# 328

# %%
mostrar(cv2.imread(vivax_names_train[r]),vivax_names_train[r]);

# %%
mostrar(cv2.imread(falciparum_names_train[r]),falciparum_names_train[r]);

# %%
mostrar(cv2.imread(white_names_train[r]),white_names_train[r]);

# %% [markdown]
# ## Data

# %%
path_model = r'F:\Dataset\ModelCNN'

# %%
image_size = 50

# %%
arquivo1= path_model + "\Cells.npy"
arquivo1
# Out:
# 'F:\\Dataset\\ModelCNN\\Cells.npy'

# %%
if os.path.exists(arquivo1):
  print(f"O arquivo {arquivo1} Está na pasta.")
  cells = np.load(path_model + "\Cells.npy")
  labels = np.load(path_model + "\Labels.npy")
  # cells = arquivo1 #Conjunto das imagens
  # labels = arquivo2 #Labels
else:
  print(f"O arquivo {arquivo1} Não está existe.")
################################################################################
  np.random.seed(123)
  data = []
  labels = []
  #print(data,labels)
  image_size = 50
  qtd=0
  inicio = time.time()
  # Separa as imagens, a adiciona mais rodando as imagens.

  print('Vivax')
  for i in vivax_names_train:
      try:

          image = cv2.imread(i)
          image_array = Image.fromarray(image , 'RGB')
          resize_img = image_array.resize((image_size , image_size))
          #rotated45 = resize_img.rotate(45) #Rotaciona
          #rotated75 = resize_img.rotate(75) #Rotaciona
          #blur = cv2.blur(np.array(resize_img) ,(10,10))
          data.append(np.array(resize_img))
          #data.append(np.array(rotated45))
          #data.append(np.array(rotated75))
          #data.append(np.array(blur))
          labels.append(1)
          #labels.append(1)
          #labels.append(1)
          #labels.append(1)
          qtd+=1
          if qtd==(tamanho//2):
            print("Metade")

      except AttributeError:
          print('error')
  qtd=0
  print('Falciparum')
  for u in falciparum_names_train:
      try:

          image = cv2.imread(u)
          image_array = Image.fromarray(image , 'RGB')
          resize_img = image_array.resize((image_size , image_size))
          #rotated45 = resize_img.rotate(45) #Rotaciona
          #rotated75 = resize_img.rotate(75) #Rotaciona
          data.append(np.array(resize_img))
          #data.append(np.array(rotated45))
          #data.append(np.array(rotated75))
          labels.append(2)
          #labels.append(0)
          #labels.append(0)
          qtd+=1
          if qtd==(tamanho//2):
            print("Metade")

      except AttributeError:
          print('error')
  qtd=0
  print('White')
  for o in white_names_train:
      try:

          image = cv2.imread(o)
          image_array = Image.fromarray(image , 'RGB')
          resize_img = image_array.resize((image_size , image_size))
          #rotated45 = resize_img.rotate(45) #Rotaciona
          #rotated75 = resize_img.rotate(75) #Rotaciona
          data.append(np.array(resize_img))
          #data.append(np.array(rotated45))
          #data.append(np.array(rotated75))
          labels.append(0)
          #labels.append(0)
          #labels.append(0)
          qtd+=1
          if qtd==(tamanho//2):
            print("Metade")

      except AttributeError:
          print('error')
  fim_treino = time.time()
  minutos_1 = round((fim_treino - inicio) / 60, 2)
  print(f'Tempo de treinamento: {minutos_1} minutos' )
  #############################################################################
  inicio = time.time()
  cells = np.array(data) #Conjunto das imagens
  labels = np.array(labels) #Labels

  np.save(path_model+'\Cells' , cells)
  np.save(path_model+'\Labels' , labels)
  fim_treino = time.time()
  minutos_2 = round((fim_treino - inicio) / 60, 2)
  print('Tempo de treinamento: ', minutos_2)
# Out:
# O arquivo F:\Dataset\ModelCNN\Cells.npy Está na pasta.

# %%
type(labels)
# Out:
# numpy.ndarray

# %%
print(f'Cells : {cells.shape} | labels : {labels.shape}')
# Out:
# Cells : (30000, 50, 50, 3) | labels : (30000,)

# %%
qtd=6 #Quantidade de imagens para plot

# %% [markdown]
# ## Plotagem 1

# %%
cells.shape[0]
# Out:
# 30000

# %%
plt.figure(1 , figsize = (20 , 10))
n = 0
for i in range(qtd*qtd):
    n += 1
    r = np.random.randint(0 , cells.shape[0] , 3)
    plt.subplot(qtd , qtd , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(cells[r[0]])
    if labels[r[0]] == 1:
      label_text = 'Vivax'
    elif labels[r[0]] == 2:
      label_text = 'Falciparum'
    else:
      label_text = 'WhiteCell'
    plt.title(f"{label_text} : {labels[r[0]]}")  # Use f-string for formatted title
    #plt.title('{} : {}'.format('Infected' if labels[r[0]] == 1 else 'Unifected' , labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# ## Plotagem 2

# %%
plt.figure(1, figsize = (15 , 7))
plt.subplot(1 , 3 , 1)
plt.imshow(cells[(tamanho-1)])
plt.title('Vivax')
plt.xticks([]) , plt.yticks([])

plt.subplot(1 , 3 , 2)
plt.imshow(cells[int(tamanho*1.5)])
plt.title('Falciparum')
plt.xticks([]) , plt.yticks([])

plt.subplot(1 , 3 , 3)
plt.imshow(cells[(int(tamanho*2.5))])#5000
plt.title('WhiteCell')
plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# ## Formatação de Imagens

# %%
# formata as imagens para um novo formato

# %%
if os.path.exists(arquivo):
  print(f"O arquivo {arquivo} Está na pasta.")
  cells = np.load(path_model + "\Cells.npy")
  labels = np.load(path_model + "\Labels.npy")
else:
  print(f"O arquivo {arquivo} Não está na pasta.")
  n = np.arange(cells.shape[0])
  #print(n)
  np.random.shuffle(n)
  inicio = time.time()
  cells = cells[n]
  labels = labels[n]
  cells = cells.astype(np.float32)
  labels = labels.astype(np.int32)
  cells = cells/255
  fim_treino = time.time()
  minutos_3 = round((fim_treino - inicio) / 60, 2)
  print('Tempo de treinamento: ', minutos_3)
  np.save(path_model+'\Cells' , cells)
  np.save(path_model+'\Labels' , labels)
# Out:
# O arquivo C:/Malaria/Tudo/dataset/test/images\TF98_CT12\20170829_201732.jpg Está na pasta.

# %%
# labels

# %% [markdown]
# ## Adiciona mais Bibliotecas

# %%
# Proximas bibliotecas a serem usadas.
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import (Conv2D,MaxPooling2D,Flatten,Dense,Dropout,)
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import keras

# %%
print(tf.__version__)
# Out:
# 2.10.1

# %% [markdown]
# ## Separando dados para Teste e Treino

# %%
inicio = time.time()
x_train , x , y_train , y = train_test_split(cells , labels , test_size = 0.2 , random_state = 43)
x_eval , x_test , y_eval , y_test = train_test_split(x , y , test_size = 0.5 , random_state = 43)
print(y_train)
y_train = to_categorical(y_train, num_classes=3) # num_classes=2
y_test = to_categorical(y_test, num_classes=3)
y_eval = to_categorical(y_eval, num_classes=3)
fim_treino = time.time()
minutos_4 = round((fim_treino - inicio) / 60, 2)
minutos_4 = max(minutos_4, 0)
print(f'Tempo de treinamento: {minutos_4}')
# Out:
# [2 2 0 ... 1 0 2]
# Tempo de treinamento: 0.0

# %%
print(f'train data shape {x_train.shape} ,eval data shape {x_eval.shape} , test data shape {x_test.shape}')
# Out:
# train data shape (24000, 50, 50, 3) ,eval data shape (3000, 50, 50, 3) , test data shape (3000, 50, 50, 3)

# %%
#print(y_train)

# %% [markdown]
# ## Definição do modelo CNN

# %%
# Definindo o modelo da CNN
model = tf.keras.Sequential()
model.add(Conv2D(128, kernel_size=(7, 7), activation="relu", input_shape=(image_size , image_size ,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(3, activation="softmax"))

# %% [markdown]
# ## Treino

# %%
# !nvidia-smi

# %%
path_model = r'F:\Dataset\ModelCNN'

# %%
arquivo_model= 'ModelCNN.h5'

# %%
# Compilando o modelo

# Caminho do arquivo que você deseja verificar
arquivo = f"{path_model}\\{arquivo_model}"

# Verifica se o arquivo existe
if os.path.exists(arquivo):
  print(f"O arquivo {arquivo} existe.")
  model= keras.models.load_model(f"{path_model}/{arquivo_model}")
else:
  print(f"O arquivo {arquivo} não existe.")
  #Define the optimizer with the desired learning rate
  optimizer = Adam(learning_rate=0.001)  # Adjust the learning rate as needed

  # Early stopping callback
  early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

  #model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

  # Compile the model specifying the optimizer
  model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  inicio = time.time()

  # Treinamento do modelo
  model.fit(x_train, y_train, epochs=50, batch_size=100, validation_split=0.2,  callbacks=[early_stopping])
  fim_treino = time.time()
  minutos_4 = round((fim_treino - inicio) / 60, 2)
  print('Tempo de treinamento: ', minutos_4)
  arquivo_model= 'ModelCNN.h5'
  model.save(f"{path_model}/ModelCNN.h5")
# Out:
# O arquivo F:\Dataset\ModelCNN\ModelCNN.h5 existe.

# %% [markdown]
# ## Avaliação do Modelo

# %%
# Avaliando o Modelo:
loss, acc = model.evaluate(x_test, y_test, verbose = 0);

print(f'Acurácia (%):  {(acc*100):.2f}')
print(f"Loss: {loss:.2f}")
# Out:
# Acurácia (%):  96.63
# Loss: 0.12

# %%
# # Avaliando o Modelo:
# # Usando os dados de avaliação (x_eval e y_eval)

# loss, acc = model.evaluate(x_eval, y_eval, verbose = 0);

# print(f'Acurácia no validador (%): {(acc*100):.2f}')
# print(f"Loss no validador: {loss:.2f}")

# %% [markdown]
# ## Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
class_names=['WhiteCell', 'Vivax', 'Falciparum']
# Faz predições no conjunto de teste
y_pred = model.predict(x_test)
y_pred_class = np.argmax(y_pred, axis=1)

# Converte rótulos para classes binárias
y_test_prob = np.argmax(y_test, axis=1)

# Calcula a matriz de confusão
conf_matrix = confusion_matrix(y_test_prob, y_pred_class)
# Out:
# 94/94 [==============================] - 0s 3ms/step

# %%
# Plotar a matriz de confusão
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# ## Precisão

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
# Calculate precision, recall, F1-score, and support
precision, recall, fscore, support = precision_recall_fscore_support(y_test_prob, y_pred_class, average=None)

# Print metrics for each class
for i, class_name in enumerate(class_names):
    print(f'Precisão ({class_name}): {(precision[i]*100):.2f}')
    print(f'Recall ({class_name}): {(recall[i]*100):.2f}')
    print(f'F1-score ({class_name}): {(fscore[i]*100):.2f}\n')

# Print macro-averaged metrics
print(f'Precisão média: {(precision.mean()*100):.2f}')  # Macro-averaged precision
print(f'Recall médio: {(recall.mean()*100):.2f}')  # Macro-averaged recall
print(f'F1-score médio: {(fscore.mean()*100):.2f}')  # Macro-averaged F1-score
# Out:
# Precisão (WhiteCell): 99.40
# Recall (WhiteCell): 99.60
# F1-score (WhiteCell): 99.50
#
# Precisão (Vivax): 95.34
# Recall (Vivax): 94.97
# F1-score (Vivax): 95.15
#
# Precisão (Falciparum): 95.13
# Recall (Falciparum): 95.32
# F1-score (Falciparum): 95.22
#
# Precisão média: 96.62
# Recall médio: 96.63
# F1-score médio: 96.63

# %% [markdown]
# ## Visualização da Previsão

# %%
#import numpy as np
from random import randint

# %%
# Faz previsões no conjunto de teste
predictions = model.predict(x_test)

# Converter as previsões em classes
predicted_classes = np.argmax(predictions, axis=1)

# Visualizar algumas imagens de teste com suas previsões
num_rows = 3
num_cols = 3
plt.figure(figsize=(12, 12))

for i in range(num_rows * num_cols):
    index = randint(0, len(x_test) - 1)
    img = x_test[index]
    true_label = y_test_prob[index]
    predicted_label = predicted_classes[index]

    if true_label==1:
      true_label="Vivax"
    elif true_label==2:
      true_label="Falciparum"
    else:
      true_label="White"

    if predicted_label==1:
      predicted_label="Vivax"
    elif predicted_label==2:
      predicted_label="Falciparum"
    else:
      predicted_label="White"

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(img)
    plt.title(f'True: {true_label}, Predicted: {predicted_label}')
    plt.axis('off')

plt.show()
# Out:
# 94/94 [==============================] - 0s 3ms/step

# %% [markdown]
# # Imagens do Yolo

# %%
len (images_yolo)
yolo_tensor = tf.convert_to_tensor(images_yolo)
yolo_array = np.array(images_yolo)

# %%
predicoes = model.predict(yolo_tensor)
vivax=0
falc =0
white=0
# Interpretar os resultados
for i, pred in enumerate(predicoes):
  # Obter a categoria com maior probabilidade
  categoria_predita = tf.argmax(pred).numpy()

  if categoria_predita==1:
    texto='vivax'
    vivax+=1
  elif categoria_predita==2:
    texto='Falciparum'
    falc+=1
  else:
    texto='White'
    white+=1

  for n in range(3):
    if pred[n] >= 0.50:  # Definir valor de limiar (ex: 0.95)
      #print(pred[n])
      if n == 1:
        texto2 = 'Vivax'
      elif n == 2:
        texto2 = 'Falciparum'
      else:
        texto2 = 'White'

  print(f"Imagem {i}: Categoria predita - {texto}, Probabilidades - {texto2}")

  # if i>=80 and i<=83:
  #   mostrar(yolo_tensor[i], texto)
  # Exibir a classificação e as probabilidades
print(f'Quantidade de Vivax: {vivax} | Falciparum: {falc} | White: {white} | Qtd total: {len (yolo_tensor)}')
# Out:
# 8/8 [==============================] - 0s 49ms/step
# Imagem 0: Categoria predita - White, Probabilidades - White
# Imagem 1: Categoria predita - White, Probabilidades - White
# Imagem 2: Categoria predita - White, Probabilidades - White
# Imagem 3: Categoria predita - White, Probabilidades - White
# Imagem 4: Categoria predita - White, Probabilidades - White
# Imagem 5: Categoria predita - White, Probabilidades - White
# Imagem 6: Categoria predita - White, Probabilidades - White
# Imagem 7: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 8: Categoria predita - White, Probabilidades - White
# Imagem 9: Categoria predita - White, Probabilidades - White
# Imagem 10: Categoria predita - White, Probabilidades - White
# Imagem 11: Categoria predita - White, Probabilidades - White
# Imagem 12: Categoria predita - White, Probabilidades - White
# Imagem 13: Categoria predita - White, Probabilidades - White
# Imagem 14: Categoria predita - White, Probabilidades - White
# Imagem 15: Categoria predita - White, Probabilidades - White
# Imagem 16: Categoria predita - White, Probabilidades - White
# Imagem 17: Categoria predita - White, Probabilidades - White
# Imagem 18: Categoria predita - White, Probabilidades - White
# Imagem 19: Categoria predita - White, Probabilidades - White
# Imagem 20: Categoria predita - White, Probabilidades - White
# Imagem 21: Categoria predita - White, Probabilidades - White
# Imagem 22: Categoria predita - White, Probabilidades - White
# Imagem 23: Categoria predita - White, Probabilidades - White
# Imagem 24: Categoria predita - White, Probabilidades - White
# Imagem 25: Categoria predita - White, Probabilidades - White
# Imagem 26: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 27: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 28: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 29: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 30: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 31: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 32: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 33: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 34: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 35: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 36: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 37: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 38: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 39: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 40: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 41: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 42: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 43: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 44: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 45: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 46: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 47: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 48: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 49: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 50: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 51: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 52: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 53: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 54: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 55: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 56: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 57: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 58: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 59: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 60: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 61: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 62: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 63: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 64: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 65: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 66: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 67: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 68: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 69: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 70: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 71: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 72: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 73: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 74: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 75: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 76: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 77: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 78: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 79: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 80: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 81: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 82: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 83: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 84: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 85: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 86: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 87: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 88: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 89: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 90: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 91: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 92: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 93: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 94: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 95: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 96: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 97: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 98: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 99: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 100: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 101: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 102: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 103: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 104: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 105: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 106: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 107: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 108: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 109: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 110: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 111: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 112: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 113: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 114: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 115: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 116: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 117: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 118: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 119: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 120: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 121: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 122: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 123: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 124: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 125: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 126: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 127: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 128: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 129: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 130: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 131: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 132: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 133: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 134: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 135: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 136: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 137: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 138: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 139: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 140: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 141: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 142: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 143: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 144: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 145: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 146: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 147: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 148: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 149: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 150: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 151: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 152: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 153: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 154: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 155: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 156: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 157: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 158: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 159: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 160: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 161: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 162: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 163: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 164: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 165: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 166: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 167: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 168: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 169: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 170: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 171: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 172: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 173: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 174: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 175: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 176: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 177: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 178: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 179: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 180: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 181: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 182: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 183: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 184: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 185: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 186: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 187: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 188: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 189: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 190: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 191: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 192: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 193: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 194: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 195: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 196: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 197: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 198: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 199: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 200: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 201: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 202: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 203: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 204: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 205: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 206: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 207: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 208: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 209: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 210: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 211: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 212: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 213: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 214: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 215: Categoria predita - Falciparum, Probabilidades - Falciparum
# Imagem 216: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 217: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 218: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 219: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 220: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 221: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 222: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 223: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 224: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 225: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 226: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 227: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 228: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 229: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 230: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 231: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 232: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 233: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 234: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 235: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 236: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 237: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 238: Categoria predita - vivax, Probabilidades - Vivax
# Imagem 239: Categoria predita - vivax, Probabilidades - Vivax
# Quantidade de Vivax: 204 | Falciparum: 11 | White: 25 | Qtd total: 240

# %%
qtd=4
plt.figure(1 , figsize = (20 , 20))
n = 0
for i in range(qtd*qtd):
    n += 1
    r = np.random.randint(0 , yolo_tensor.shape[0] , 3)
    plt.subplot(qtd , qtd , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(yolo_tensor[r[0]])
    label_text= f'Celula'
    # if labels[r[0]] == 1:
    #   label_text = 'Vivax'
    # elif labels[r[0]] == 2:
    #   label_text = 'Falciparum'
    # else:
    #   label_text = 'WhiteCell'
    plt.title(f"{label_text} ")#: {labels[r[0]]}")  # Use f-string for formatted title
    #plt.title('{} : {}'.format('Infected' if labels[r[0]] == 1 else 'Unifected' , labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
# if minutos_2<0:
#   minutos_2=0
# if minutos_3<0:
#   minutos_3=0
# print(f'Tempo 1:{minutos_1} | Tempo 2: {minutos_2} | Tempo 3: {minutos_3} | Tempo 4: {minutos_4} Tempo Total: {minutos_1+minutos_2+minutos_3+minutos_4}')
# Out:
# Tempo 1:20.26 | Tempo 2: 0 | Tempo 3: 0 | Tempo 4: 2.63 Tempo Total: 22.89

# %%
#model1= keras.models.load_model(f"{path_model}/ModelCNN.h5")

# %%
#  cells = None
#  data = None
