# %% [markdown]
# <a href="https://colab.research.google.com/github/Caosbot/Treinos_Python/blob/Machine_Learning/Mal%C3%A1ria_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conectar ao Google Drive
#from google.colab import drive
#drive.mount("/content/drive")

# %%
# Importar alguns dos módulos necessários
import os
#import zipfile
import cv2
from PIL import Image
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
main = r'F:\Dataset\CNN'
vivax_path_train = r'F:\Dataset\CNN\Vivax\Train'
vivax_path_valid = r'F:\Dataset\CNN\Vivax\Valid'
vivax_path_test = r'F:\Dataset\CNN\Vivax\Test'
falciparum_path = r'F:\Dataset\CNN\Falciparum'
white_path = r'F:\Dataset\CNN\WhiteBloodCells'

# %%
vivax_names_train = [os.path.join(vivax_path_train,f) for f in os.listdir(vivax_path_train)]
vivax_names_valid = [os.path.join(vivax_path_valid,f) for f in os.listdir(vivax_path_valid)]
vivax_names_test = [os.path.join(vivax_path_test,f) for f in os.listdir(vivax_path_test)]
vivax_names = vivax_names_train+vivax_names_valid+vivax_names_test
falciparum_names = [os.path.join(falciparum_path,f) for f in os.listdir(falciparum_path)]
white_names = [os.path.join(white_path,f) for f in os.listdir(white_path)]

# %%
vivax_train_qtd =  len(vivax_names_train)
vivax_valid_qtd =  len(vivax_names_valid)
vivax_test_qtd =  len(vivax_names_test)
vivax_qtd =  len(vivax_names)
falciparum_qtd = len(falciparum_names)
white_qtd = len(white_names)
vivax_total = vivax_train_qtd+vivax_valid_qtd+vivax_test_qtd
print(f'vivax_qtd: {vivax_qtd}\nfalciparum_qtd: {falciparum_qtd}\nwhite_names: {white_qtd}')
# Out:
# vivax_qtd: 25706
# falciparum_qtd: 84509
# white_names: 35449

# %%
def Dividir_data (valor_total):
  para_treino = 70
  para_teste = 20
  para_validacao = 10

  para_treinor = math.floor(valor_total * (para_treino / 100))
  para_tester = math.floor(valor_total * (para_teste / 100))
  para_validacaor = math.floor(valor_total * (para_validacao / 100))

  #para_treinor = valor_total * (para_treino / 100) - para_treinor
  #para_tester = valor_total * (para_teste / 100) - para_tester
  #para_validacaor = valor_total * (para_validacao / 100) - para_validacaor

  print(f"{para_treino}% de {valor_total} é {para_treinor:.0f}")
  print(f"{para_teste}% de {valor_total} é {para_tester:.0f}")
  print(f"{para_validacao}% de {valor_total} é {para_validacaor:.0f}")

# %%
print ('Vivax')
Dividir_data(vivax_total)
print ('\nFalciparum')
Dividir_data(falciparum_qtd)
print ('\nWhiteCell')
Dividir_data(white_qtd)
# Out:
# Vivax
# 70% de 25706 é 17994
# 20% de 25706 é 5141
# 10% de 25706 é 2570
#
# Falciparum
# 70% de 84509 é 59156
# 20% de 84509 é 16901
# 10% de 84509 é 8450
#
# WhiteCell
# 70% de 35449 é 24814
# 20% de 35449 é 7089
# 10% de 35449 é 3544

# %%
falciparum_names_train = falciparum_names[:17994]
vivax_names_train = vivax_names[:17994]
white_names_train = white_names[:17994]

# %%
def mostrar(imagem,title):
  fig = plt.gcf()
  fig.set_size_inches(20,10)
  plt.imshow(imagem, cmap='gray')
  plt.title(title)
  plt.axis('off')
  plt.show()

# %%
r =np.random.randint(0,len(vivax_names_train))
r
# Out:
# 4979

# %%
mostrar(cv2.imread(vivax_names_train[r]),vivax_names_train[r]);

# %%
mostrar(cv2.imread(falciparum_names_train[r]),falciparum_names_train[r]);

# %%
mostrar(cv2.imread(white_names_train[r]),white_names_train[r]);

# %%
'''
fulldata=None
infected = os.listdir('cell_images/Parasitized/')
print('Quantidade de céluas infectadas:',len(infected))
uninfected  = os.listdir('cell_images/Uninfected/')
print('Quantidade de célas saudaveis:',len(uninfected))
cellDataset=None
'''
# Out:
# "\nfulldata=None\ninfected = os.listdir('cell_images/Parasitized/')\nprint('Quantidade de céluas infectadas:',len(infected))\nuninfected  = os.listdir('cell_images/Uninfected/')\nprint('Quantidade de célas saudaveis:',len(uninfected))\ncellDataset=None\n"

# %% [markdown]
# # Data

# %%
np.random.seed(123)
data = []
labels = []
print(data,labels)
# Separa as imagens, a adiciona mais rodando as imagens.

for i in vivax_names_train:
    try:

        image = cv2.imread(i)
        image_array = Image.fromarray(image , 'RGB')
        resize_img = image_array.resize((50 , 50))
        #rotated45 = resize_img.rotate(45) #Rotaciona
        #rotated75 = resize_img.rotate(75) #Rotaciona
        #blur = cv2.blur(np.array(resize_img) ,(10,10))
        data.append(np.array(resize_img))
        #data.append(np.array(rotated45))
        #data.append(np.array(rotated75))
        #data.append(np.array(blur))
        labels.append(0)
        #labels.append(1)
        #labels.append(1)
        #labels.append(1)

    except AttributeError:
        print('error')

for u in falciparum_names_train:
    try:

        image = cv2.imread(u)
        image_array = Image.fromarray(image , 'RGB')
        resize_img = image_array.resize((50 , 50))
        #rotated45 = resize_img.rotate(45) #Rotaciona
        #rotated75 = resize_img.rotate(75) #Rotaciona
        data.append(np.array(resize_img))
        #data.append(np.array(rotated45))
        #data.append(np.array(rotated75))
        labels.append(1)
        #labels.append(0)
        #labels.append(0)

    except AttributeError:
        print('error')

# for o in white_names_train:
#     try:

#         image = cv2.imread(o)
#         image_array = Image.fromarray(image , 'RGB')
#         resize_img = image_array.resize((50 , 50))
#         #rotated45 = resize_img.rotate(45) #Rotaciona
#         #rotated75 = resize_img.rotate(75) #Rotaciona
#         data.append(np.array(resize_img))
#         #data.append(np.array(rotated45))
#         #data.append(np.array(rotated75))
#         labels.append(0)
#         #labels.append(0)
#         #labels.append(0)

    except AttributeError:
        print('error')
# Out:
# [] []

# %%
cells = np.array(data) #Conjunto das imagens
labels = np.array(labels) #Labels

np.save('Cells' , cells)
np.save('Labels' , labels)

# %%
type(labels)
# Out:
# numpy.ndarray

# %%
print(f'Cells : {cells.shape} | labels : {labels.shape}')
# Out:
# Cells : (35988, 50, 50, 3) | labels : (35988,)

# %%
qtd=7 #Quantidade de imagens para plot

# %% [markdown]
# # Plotagem 1

# %%
cells.shape[0]
# Out:
# 35988

# %%
plt.figure(1 , figsize = (20 , 10))
n = 0
for i in range(qtd*qtd):
    n += 1
    r = np.random.randint(0 , cells.shape[0] , 3)
    plt.subplot(qtd , qtd , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(cells[r[0]])
    if labels[r[0]] == 0:
      label_text = 'Vivax'
    elif labels[r[0]] == 1:
      label_text = 'Falciparum'
    else:
      label_text = 'WhiteCell'
    plt.title(f"{label_text} : {labels[r[0]]}")  # Use f-string for formatted title
    #plt.title('{} : {}'.format('Infected' if labels[r[0]] == 1 else 'Unifected' , labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# # Plotagem 2

# %%
plt.figure(1, figsize = (15 , 7))
plt.subplot(1 , 3 , 1)
plt.imshow(cells[0])
plt.title('Vivax')
plt.xticks([]) , plt.yticks([])

plt.subplot(1 , 3 , 2)
plt.imshow(cells[20000])
plt.title('Falciparum')
plt.xticks([]) , plt.yticks([])

# plt.subplot(1 , 3 , 3)
# plt.imshow(cells[20000])#5000
# plt.title('WhiteCell')
# plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# # Formatação de Imagens

# %%
# formata as imagens para um novo formato
n = np.arange(cells.shape[0])
print(n)
np.random.shuffle(n)
# Out:
# [    0     1     2 ... 35985 35986 35987]

# %%
cells = cells[n]
labels = labels[n]
cells = cells.astype(np.float32)
labels = labels.astype(np.int32)
cells = cells/255

# %%
labels
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %% [markdown]
# # Adiciona mais Bibliotecas

# %%
# Proximas bibliotecas a serem usadas.
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import (Conv2D,MaxPooling2D,Flatten,Dense,Dropout,)
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import time

# %% [markdown]
# # Separando dados para Teste e Treino

# %%
x_train , x , y_train , y = train_test_split(cells , labels , test_size = 0.2 , random_state = 43)
x_eval , x_test , y_eval , y_test = train_test_split(x , y , test_size = 0.5 , random_state = 43)
y_train = to_categorical(y_train, num_classes=2) # num_classes=2
y_test = to_categorical(y_test, num_classes=2)

# %%
print(f'train data shape {x_train.shape} ,eval data shape {x_eval.shape} , test data shape {x_test.shape}')
# Out:
# train data shape (28790, 50, 50, 3) ,eval data shape (3599, 50, 50, 3) , test data shape (3599, 50, 50, 3)

# %% [markdown]
# # Definição do modelo CNN

# %%
# Definindo o modelo da CNN
model = tf.keras.Sequential()
model.add(Conv2D(128, kernel_size=(7, 7), activation="relu", input_shape=(50 , 50 ,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(2, activation="softmax"))

# %% [markdown]
# # Treino

# %%
# !nvidia-smi
# Out:
# Mon May 27 21:51:15 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.23                 Driver Version: 551.23         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   44C    P8              4W /   50W |    2412MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     16036      C   ...rs\david\.conda\envs\GPU\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Compilando o modelo
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
st = time.time()

# Treinamento do modelo
model.fit(x_train, y_train, epochs=100, batch_size=100, validation_split=0.2)
et = time.time()
tempo_decorrido = et - st
# Out:
# Epoch 1/100
# 231/231 [==============================] - 7s 27ms/step - loss: 0.3825 - accuracy: 0.8242 - val_loss: 0.2269 - val_accuracy: 0.9133
# Epoch 2/100
# 231/231 [==============================] - 6s 28ms/step - loss: 0.2323 - accuracy: 0.9159 - val_loss: 0.1961 - val_accuracy: 0.9290
# Epoch 3/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.1924 - accuracy: 0.9322 - val_loss: 0.1812 - val_accuracy: 0.9354
# Epoch 4/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.1682 - accuracy: 0.9403 - val_loss: 0.1517 - val_accuracy: 0.9476
# Epoch 5/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.1555 - accuracy: 0.9456 - val_loss: 0.1580 - val_accuracy: 0.9449
# Epoch 6/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.1386 - accuracy: 0.9503 - val_loss: 0.1304 - val_accuracy: 0.9526
# Epoch 7/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.1162 - accuracy: 0.9583 - val_loss: 0.1092 - val_accuracy: 0.9613
# Epoch 8/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.1092 - accuracy: 0.9599 - val_loss: 0.1073 - val_accuracy: 0.9621
# Epoch 9/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.
100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0214 - val_accuracy: 0.9969
# Epoch 81/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0961 - accuracy: 0.9828 - val_loss: 0.0991 - val_accuracy: 0.9771
# Epoch 82/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.0711 - val_accuracy: 0.9870
# Epoch 83/100
# 231/231 [==============================] - 6s 28ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0369 - val_accuracy: 0.9939
# Epoch 84/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0328 - val_accuracy: 0.9955
# Epoch 85/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0353 - val_accuracy: 0.9958
# Epoch 86/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0474 - val_accuracy: 0.9934
# Epoch 87/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0379 - val_accuracy: 0.9953
# Epoch 88/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0271 - val_accuracy: 0.9967
# Epoch 89/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0359 - val_accuracy: 0.9951
# Epoch 90/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0432 - val_accuracy: 0.9931
# Epoch 91/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0295 - val_accuracy: 0.9964
# Epoch 92/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0515 - val_accuracy: 0.9960
# Epoch 93/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0324 - val_accuracy: 0.9936
# Epoch 94/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0276 - val_accuracy: 0.9965
# Epoch 95/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0257 - val_accuracy: 0.9967
# Epoch 96/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 0.0369 - val_accuracy: 0.9932
# Epoch 97/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0296 - val_accuracy: 0.9965
# Epoch 98/100
# 231/231 [==============================] - 6s 27ms/step - loss: 7.2608e-04 - accuracy: 0.9998 - val_loss: 0.0283 - val_accuracy: 0.9970
# Epoch 99/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0430 - val_accuracy: 0.9937
# Epoch 100/100
# 231/231 [==============================] - 6s 27ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0576 - val_accuracy: 0.9951

# %% [markdown]
# # Avaliação do Modelo

# %%
# Avaliando o Modelo:
loss, acc = model.evaluate(x_test, y_test, verbose = 0);

print(f'Acurácia (%):  {(acc*100):.2f}')
print(f"Loss: {loss:.2f}")
print (f'Tempo decorrido: {tempo_decorrido:.2f}')
# Out:
# Acurácia (%):  99.75
# Loss: 0.01
# Tempo decorrido: 621.51

# %% [markdown]
# # Inicio Tunnel

# %%
# Instalação das dependências necessárias
# !pip install -q tensorflow-addons

# Importe de bibliotecas necessárias
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras import layers, models
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 12.9 MB/s eta 0:00:00
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
def create_vit_model(input_shape=(50, 50, 3), num_classes=3):
    vit_model = tf.keras.applications.VGG16(
        include_top=False, input_shape=input_shape, weights='imagenet'
    )

    # Congela as camadas do ViT
    vit_model.trainable = False

    # Adapta as dimensões da saída do ViT para a entrada de uma camada Dense
    global_average_layer = layers.GlobalAveragePooling2D()
    dense_layer_1 = layers.Dense(128, activation='relu')
    dense_layer_2 = layers.Dense(64, activation='relu')
    dense_layer_3 = layers.Dense(32, activation='relu')
    dropout_layer = layers.Dropout(0.2)
    output_layer = layers.Dense(num_classes, activation='softmax')

    # Cria o modelo
    model = models.Sequential([
        vit_model,
        global_average_layer,
        dense_layer_1,
        dense_layer_2,
        dense_layer_3,
        dropout_layer,
        output_layer
    ])

    return model

# %%
# Cria e compilar o modelo ViT
vit_model = create_vit_model()
vit_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
# Treina o modelo
stVit = time.time()
vit_model.fit(x_train, y_train, epochs=10, batch_size=100, validation_split=0.2)
etVit = time.time()
tempo_decorridoVit = etVit - stVit
# Out:
# Epoch 1/10
# 618/618 [==============================] - 39s 53ms/step - loss: 0.2982 - accuracy: 0.8773 - val_loss: 0.2487 - val_accuracy: 0.8928
# Epoch 2/10
# 618/618 [==============================] - 25s 40ms/step - loss: 0.2335 - accuracy: 0.9065 - val_loss: 0.2137 - val_accuracy: 0.9116
# Epoch 3/10
# 618/618 [==============================] - 24s 38ms/step - loss: 0.2185 - accuracy: 0.9117 - val_loss: 0.2040 - val_accuracy: 0.9136
# Epoch 4/10
# 618/618 [==============================] - 25s 40ms/step - loss: 0.2094 - accuracy: 0.9158 - val_loss: 0.2170 - val_accuracy: 0.9035
# Epoch 5/10
# 618/618 [==============================] - 24s 39ms/step - loss: 0.2015 - accuracy: 0.9188 - val_loss: 0.2195 - val_accuracy: 0.9075
# Epoch 6/10
# 618/618 [==============================] - 25s 40ms/step - loss: 0.1981 - accuracy: 0.9208 - val_loss: 0.2166 - val_accuracy: 0.9044
# Epoch 7/10
# 618/618 [==============================] - 25s 41ms/step - loss: 0.1918 - accuracy: 0.9236 - val_loss: 0.2001 - val_accuracy: 0.9154
# Epoch 8/10
# 618/618 [==============================] - 24s 38ms/step - loss: 0.1860 - accuracy: 0.9258 - val_loss: 0.1953 - val_accuracy: 0.9188
# Epoch 9/10
# 618/618 [==============================] - 24s 39ms/step - loss: 0.1839 - accuracy: 0.9269 - val_loss: 0.1917 - val_accuracy: 0.9244
# Epoch 10/10
# 618/618 [==============================] - 25s 40ms/step - loss: 0.1801 - accuracy: 0.9283 - val_loss: 0.2037 - val_accuracy: 0.9207

# %%
# Avalia o modelo
lossVit, accVit = vit_model.evaluate(x_test, y_test, verbose=0)
print(f'Acurácia (%):  {(acc*100):.2f}')
print(f"Loss: {loss:.2f}")
print (f'Tempo decorrido: {tempo_decorridoVit:.2f}')
# Out:
# Acurácia (%):  96.21
# Loss: 0.11
# Tempo decorrido: 269.84

# %% [markdown]
# # Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Faz predições no conjunto de teste
y_pred = model.predict(x_test)
y_pred_class = np.argmax(y_pred, axis=1)

# Converte rótulos para classes binárias
y_test_binary = np.argmax(y_test, axis=1)

# Calcula a matriz de confusão
conf_matrix = confusion_matrix(y_test_binary, y_pred_class)
# Out:
# 113/113 [==============================] - 0s 3ms/step

# %%
# Plotar a matriz de confusão
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# # Precisão

# %%
from sklearn.metrics import precision_score

# %%
# Calcular a precisão
precision = precision_score(y_test_binary, y_pred_class)

print(f'Precisão: {(precision*100):.2f}')
# Out:
# Precisão: 99.72

# %% [markdown]
# # Visualização da Previsão

# %%
#import numpy as np
from random import randint

# %%
# Faz previsões no conjunto de teste
predictions = model.predict(x_test)

# Converter as previsões em classes
predicted_classes = np.argmax(predictions, axis=1)

# Visualizar algumas imagens de teste com suas previsões
num_rows = 3
num_cols = 3
plt.figure(figsize=(12, 12))

for i in range(num_rows * num_cols):
    index = randint(0, len(x_test) - 1)
    img = x_test[index]
    true_label = y_test_binary[index]
    predicted_label = predicted_classes[index]

    if true_label==0:
      true_label="Vivax"
    else:
      true_label="Falciparum"

    if predicted_label==0:
      predicted_label="Vivax"
    else:
      predicted_label="Falciparum"

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(img)
    plt.title(f'True: {true_label}, Predicted: {predicted_label}')
    plt.axis('off')

plt.show()
# Out:
# 113/113 [==============================] - 1s 5ms/step
