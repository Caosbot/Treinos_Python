# %% [markdown]
# <a href="https://colab.research.google.com/github/Caosbot/Treinos_Python/blob/Data_Science/Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instruções inicial Python

# %% [markdown]
# ## Bibliotecas

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import sidetable
from ydata_profiling import ProfileReport
import missingno as msno
from ipywidgets import interact, widgets

from sklearn import datasets
from sklearn.preprocessing import scale, minmax_scale, power_transform
# Out:
#         <div>
#             <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#             <p>
#                 Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#             </p>
#         </div>

# %% [markdown]
# ## Funções para implementação e visualização

# %%
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.8,
    rc={
        'figure.figsize': (12,8)
    }
)

# %%
def list_attributes(obj):
  """Lista atributos e funções de um objeto"""
  return [attr for attr in obj.__dir__() if not attr.startswith('_')]

# %% [markdown]
# # Inicio da Analise

# %% [markdown]
# ## Dataset e informações sobre o Dataset

# %%
# Lendo titanic dataset
df = pd.read_csv('https://raw.githubusercontent.com/adamerose/datasets/master/titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.13.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-03-13 13:47:33.827146&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %% [markdown]
# ## Valores Duplicados

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Verifica a quantidade de linhas duplicadas.
df.duplicated(keep=False).sum()
# Out:
# 160

# %%
df[df.duplicated(keep=False)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 28          1       3  female   NaN      0      0   7.8792        Q   Third
# 29          0       3    male   NaN      0      0   7.8958        S   Third
# 32          1       3  female   NaN      0      0   7.7500        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
df.groupby(df.columns.tolist()).size()
# Out:
# survived  pclass  sex     age   sibsp  parch  fare      embarked  class  who    adult_male  deck  embark_town  alive  alone
# 0         1       female  2.0   1      2      151.5500  S         First  child  False       C     Southampton  no     False    1
#                           25.0  1      2      151.5500  S         First  woman  False       C     Southampton  no     False    1
#                           50.0  0      0      28.7125   C         First  woman  False       C     Cherbourg    no     True     1
#                   male    18.0  1      0      108.9000  C         First  man    True        C     Cherbourg    no     False    1
#                           19.0  1      0      53.1000   S         First  man    True        D     Southampton  no     False    1
#                                                                                                                               ..
# ...

# %%
(
 df
 .groupby(df.columns.tolist(), dropna=False) #permite evolver no groupby valores nulos
 .size()
 .to_frame('duplicados')
 .query('duplicados>1')
 .sort_values('duplicados', ascending=False)
 .head(5)
)
# Out:
#                                                                                                              duplicados
# survived pclass sex    age sibsp parch fare   embarked class  who   adult_male deck embark_town alive alone
# 0        3      male   NaN 0     0     7.8958 S        Third  man   True       NaN  Southampton no    True           13
#                                        8.0500 S        Third  man   True       NaN  Southampton no    True           12
#                                        7.7500 Q        Third  man   True       NaN  Queenstown  no    True            8
# 1        3      female NaN 0     0     7.7500 Q        Third  woman False      NaN  Queenstown  yes   True            7
# 0        2      male   NaN 0     0     0.0000 S        Second man   True       NaN  Southampton no    True            6

# %%
#Removendo Duplicados
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Tratamento de Nulos

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isna().sum() / df.shape[0] *100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df_faltante = (
    df
    .isna().sum()
    .to_frame('falta_conta')
    .join((df.isna().sum()/ df.shape[0]).to_frame('falta_pct'))
    .sort_values('falta_conta', ascending=False)
    .style.format('{:.2%}', subset=['falta_pct'])#formatada a coluna 'falta_pct' para exibir 2 casas decimais e em porcentagem
    )
df_faltante
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0d5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0d5e_level0_col0" class="col_heading level0 col0" >falta_conta</th>
#       <th id="T_d0d5e_level0_col1" class="col_heading level0 col1" >falta_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0d5e_level0_row0" class="row_heading level0 row0" >deck</th>
#       <td id="T_d0d5e_row0_col0" class="data row0 col0" >688</td>
#       <td id="T_d0d5e_row0_col1" class="data row0 col1" >77.22%</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5e_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_d0d5e_row1_col0" class="data row1 col0" >177</td>
#       <td id="T_d0d5e_row1_col1" class="data row1 col1" >19.87%</td>
#     </tr>
#     <tr>
#       <th id="T_d0d5e_level0_row2" class="row_heading level0 row2" >embarked</th>
#       <td id="T_d0d5e_row2_col0" class="data row2 col0" >2</td>
# ...

# %% [markdown]
# Método com sintaxe em cadeia:

# %%
df.isna().sum().to_frame('falta_conta').assign(falta_pct = lambda x: x.div(len(df))).sort_values('falta_conta', ascending=False).style.format('{:.2%}', subset=['falta_pct'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4845">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4845_level0_col0" class="col_heading level0 col0" >falta_conta</th>
#       <th id="T_b4845_level0_col1" class="col_heading level0 col1" >falta_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4845_level0_row0" class="row_heading level0 row0" >deck</th>
#       <td id="T_b4845_row0_col0" class="data row0 col0" >688</td>
#       <td id="T_b4845_row0_col1" class="data row0 col1" >77.22%</td>
#     </tr>
#     <tr>
#       <th id="T_b4845_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_b4845_row1_col0" class="data row1 col0" >177</td>
#       <td id="T_b4845_row1_col1" class="data row1 col1" >19.87%</td>
#     </tr>
#     <tr>
#       <th id="T_b4845_level0_row2" class="row_heading level0 row2" >embarked</th>
#       <td id="T_b4845_row2_col0" class="data row2 col0" >2</td>
# ...

# %% [markdown]
# Mostrando as linhas com valores faltantes como um todo

# %%
df.isna().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
df.isna().any(axis=1)#Gera um array
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
df[df.isna().any(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Mostrando as linhas com valores faltantes na coluna 'embarked'

# %%
df[df.embarked.isna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %% [markdown]
# ### Utilizando sidetable

# %%
df.stb.missing(style=True)#style = false é o padrão,
# Out:
# <style type="text/css">
# </style>
# <table id="T_d47c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d47c3_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_d47c3_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_d47c3_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d47c3_level0_row0" class="row_heading level0 row0" >deck</th>
#       <td id="T_d47c3_row0_col0" class="data row0 col0" >688</td>
#       <td id="T_d47c3_row0_col1" class="data row0 col1" >891</td>
#       <td id="T_d47c3_row0_col2" class="data row0 col2" >77.22%</td>
#     </tr>
#     <tr>
#       <th id="T_d47c3_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_d47c3_row1_col0" class="data row1 col0" >177</td>
#       <td id="T_d47c3_row1_col1" class="data row1 col1" >891</td>
# ...

# %% [markdown]
# ### Utilizando missgno

# %%
#No meu caso uso o colab com hospedagem local, isso auxilia na plotagem do missgno
# %matplotlib inline

# %%
msno.bar(df)
plt.show()

# %%
msno.matrix(df);
plt.show()

# %% [markdown]
# ## Removendo valores nulos

# %% [markdown]
# Coluna deck

# %%
df.dropna(subset=['deck']) #Perde muitos dados
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.drop(columns=['deck'])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# Determinando NA

# %%
max_nan = .7
na_cols = df.isna().sum().div(len(df))
print(na_cols)
cols2drop = na_cols[na_cols>max_nan].index
print(f"\n Cols2drop {cols2drop}")
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64
#
#  Cols2drop Index(['deck'], dtype='object')

# %%
df.drop(columns=cols2drop)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.drop(columns=cols2drop, inplace=True)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# ## Imputando valores nulos

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True

# %%
df.fillna(0).tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   0.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True

# %%
df.fillna({'age': int(df.age.mean())}).tail()#'embarked': df.embarked.mode([0])
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  29.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True

# %% [markdown]
# Imputando valores nulos com valores passados, futuros, ou via interpolação

# %%
df.fillna(method='bfill').tail()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_16252\1217501410.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill').tail()
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  26.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# ...

# %%
df.bfill().tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  26.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True

# %%
df.ffill().tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  19.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True

# %%
df.fillna({'age': df.age.interpolate(method='linear').astype(int)}).tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  22.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True

# %%
(
  df
 .assign(
     age_bfill = df.age.bfill(),
     age_ffill = df.age.ffill(),
     age_interpolate = df.age.interpolate()
 )
 .filter(like='age')
 .tail()
 .style.highlight_null('red').format('{:.0f}')
)
# Out:
# <style type="text/css">
# #T_7743f_row2_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_7743f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7743f_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_7743f_level0_col1" class="col_heading level0 col1" >age_bfill</th>
#       <th id="T_7743f_level0_col2" class="col_heading level0 col2" >age_ffill</th>
#       <th id="T_7743f_level0_col3" class="col_heading level0 col3" >age_interpolate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7743f_level0_row0" class="row_heading level0 row0" >886</th>
#       <td id="T_7743f_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_7743f_row0_col1" class="data row0 col1" >27</td>
#       <td id="T_7743f_row0_col2" class="data row0 col2" >27</td>
#       <td id="T_7743f_row0_col3" class="data row0 col3" >27</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Imputando NA por grupo

# %%
df.groupby('sex')['age'].apply(lambda x : x.fillna(x.mean()))
# Out:
# sex
# female  1      38.0
#         2      26.0
#         3      35.0
#         8      27.0
#         9      14.0
#                ...
# male    883    28.0
#         884    25.0
#         886    27.0
#         889    26.0
#         890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# ## Outliers

# %%
df,_ = datasets.load_wine(return_X_y=True, as_frame=True)
print(df.shape)
df.head()
# Out:
# (178, 13)
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %% [markdown]
# ### Identificando/removendo outliers

# %% [markdown]
# #### Através de boxplot

# %%
df.plot.box()
plt.xticks(rotation=60, ha='right');

# %%
#df.apply(scale)
df.apply(scale).plot.box()
plt.xticks(rotation=60, ha='right');

# %% [markdown]
# Podemos identificar os outliers pelo método interquatril, utilizando a seguinte formula:
#
#
# **lower_oulier = Q1 - 1.5 x IQR**
#
# **upper_oulier = Q3 + 1.5 x IQR**
#
#
# onde **Q1** represente o primeiro quartil, **Q3** o terceiro, e **IQR** o intervalo interquertil.

# %%
def is_outlier(array, extreme=False):
  """Custom funtion to identify outliers in an array"""
  q1, q3 = np.quantile(array, [.25,.75])
  iqr = q3-q1

  factor = 3. if extreme else 1.5
  upper_outlier = q3+factor*iqr
  lower_oulier = q1-factor*iqr

  return (array < lower_oulier) | (array> upper_outlier)

# %% [markdown]
# outlier na coluna ash

# %%
is_outlier(df.ash)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# Name: ash, Length: 178, dtype: bool

# %%
is_outlier(df.ash).sum()
# Out:
# 3

# %%
df.apply(is_outlier)
# Out:
#      alcohol  malic_acid    ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      False       False  False              False      False          False
# 1      False       False  False              False      False          False
# 2      False       False  False              False      False          False
# 3      False       False  False              False      False          False
# 4      False       False  False              False      False          False
# ..       ...         ...    ...                ...        ...            ...
# 173    False        True  False              False      False          False
# 174    False       False  False              False      False          False
# 175    False       False  False              False      False          False
# 176    False       False  False              False      False          False
# 177    False       False  False              False      False          False
#
# ...

# %%
df.apply(is_outlier).sum()
# Out:
# alcohol                         0
# malic_acid                      3
# ash                             3
# alcalinity_of_ash               4
# magnesium                       4
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 2
# color_intensity                 4
# hue                             1
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %%
df.apply(is_outlier).any(axis=0)#Aplicado por coluna
# Out:
# alcohol                         False
# malic_acid                       True
# ash                              True
# alcalinity_of_ash                True
# magnesium                        True
# total_phenols                   False
# flavanoids                      False
# nonflavanoid_phenols            False
# proanthocyanins                  True
# color_intensity                  True
# hue                              True
# od280/od315_of_diluted_wines    False
# proline                         False
# dtype: bool

# %%
df.apply(is_outlier).any(axis=1)#Aplicado por linha
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 173     True
# 174    False
# 175    False
# 176    False
# 177    False
# Length: 178, dtype: bool

# %%
df[df.apply(is_outlier).any(axis=1)]#São outliers
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 25     13.05        2.05  3.22               25.0      124.0           2.63
# 59     12.37        0.94  1.36               10.6       88.0           1.98
# 69     12.21        1.19  1.75               16.8      151.0           1.85
# 73     12.99        1.67  2.60               30.0      139.0           3.30
# 78     12.33        0.99  1.95               14.8      136.0           1.90
# 95     12.47        1.52  2.20               19.0      162.0           2.50
# 110    11.46        3.74  1.82               19.5      107.0           3.18
# 115    11.03        1.51  2.20               21.5       85.0           2.46
# 121    11.56        2.05  3.23               28.5      119.0           3.18
# 123    13.05        5.80  2.13               21.5       86.0           2.62
# 127    11.79        2.13  2.78               28.5       92.0           2.13
# ...

# %%
df[~df.apply(is_outlier).any(axis=1)]#Não são outliers
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 172    14.16        2.51  2.48               20.0       91.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df_sem_outliers=df[~df.apply(is_outlier).any(axis=1)]
df_sem_outliers.apply(is_outlier).sum()
# Out:
# alcohol                         0
# malic_acid                      1
# ash                             3
# alcalinity_of_ash               2
# magnesium                       1
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 3
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %%
fig,axes = plt.subplots(ncols=2, figsize=(18,6))

df.apply(scale).plot.box(ax=axes[0], title = "SEM filtro de outliers")
df_sem_outliers.apply(scale).plot.box(ax=axes[1], title = "COM filtro de outliers")

fig.autofmt_xdate(rotation=60, ha='right')

plt.show()

# %% [markdown]
# #### Z-score

# %% [markdown]
# Outro método para identificar e também remover outliers é através da padronização Z-score, em que a média dos valores fica em 0, e o desvio padrão em 1. Usualmente, filtramos valores acima e abaixo de 3 desvios padrões (para cima e para baixo, respectivamente).

# %%
def zscore_outlier(array):
  scaled_array = scale(array)
  return (scaled_array<-3) | (scaled_array>3)

df_sem_outliers = df[~df.apply(zscore_outlier).any(axis=1)]

# %%
fig,axes = plt.subplots(ncols=2, figsize=(18,6))

df.apply(scale).plot.box(ax=axes[0], title = "SEM filtro de outliers")
df_sem_outliers.apply(scale).plot.box(ax=axes[1], title = "COM filtro de outliers")

fig.autofmt_xdate(rotation=60, ha='right')

plt.show()

# %% [markdown]
# #### Corrigindo outliers

# %%
df.describe(percentiles=[.01, .25, .5, .75, .9, .99])
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 1%      11.440800    0.897700    1.700000          11.354000   78.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# 90%     14.100000    3.983000    2.700000          24.000000  118.000000
# 99%     14.472800    5.542200    2.989000          28.500000  141.760000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# ...

# %%
def cap_values(array, lower_quantile=0., upper_quantile=1.):
  array = array.copy()

  lower_quantile = np.quantile(array, lower_quantile)
  upper_quantile = np.quantile(array, upper_quantile)

  array[array<lower_quantile] = lower_quantile
  array[array>upper_quantile] = upper_quantile

  return array

# %%
# Mostrando percentis após aplicar função
cap_values(df.ash, upper_quantile=.90).max()
# Out:
# 2.7

# %%
df.apply(cap_values, upper_quantile=.99)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23      1.7100  2.43               15.6      127.0         2.8000
# 1      13.20      1.7800  2.14               11.2      100.0         2.6500
# 2      13.16      2.3600  2.67               18.6      101.0         2.8000
# 3      14.37      1.9500  2.50               16.8      113.0         3.5959
# 4      13.24      2.5900  2.87               21.0      118.0         2.8000
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71      5.5422  2.45               20.5       95.0         1.6800
# 174    13.40      3.9100  2.48               23.0      102.0         1.8000
# 175    13.27      4.2800  2.26               20.0      120.0         1.5900
# 176    13.17      2.5900  2.37               20.0      120.0         1.6500
# 177    14.13      4.1000  2.74               24.5       96.0         2.0500
#
# ...

# %%
df.apply(cap_values, upper_quantile=.99).describe(percentiles=[.01, .25, .5, .75, .9, .99])
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    12.997054    2.334294    2.363865          19.486517   99.575955
# std      0.804575    1.111002    0.267036           3.314706   13.680946
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 1%      11.440800    0.897700    1.700000          11.354000   78.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# 90%     14.100000    3.983000    2.700000          24.000000  118.000000
# 99%     14.409044    5.517406    2.935870          28.500000  139.634800
# max     14.472800    5.542200    2.989000          28.500000  141.760000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# ...

# %% [markdown]
# #### Transformações

# %% [markdown]
# ##### Log

# %%
df.apply(np.log)
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    2.655352    0.536493  0.887891           2.747271   4.844187
# 1    2.580217    0.576613  0.760806           2.415914   4.605170
# 2    2.577182    0.858662  0.982078           2.923162   4.615121
# 3    2.665143    0.667829  0.916291           2.821379   4.727388
# 4    2.583243    0.951658  1.054312           3.044522   4.770685
# ..        ...         ...       ...                ...        ...
# 173  2.618125    1.731656  0.896088           3.020425   4.553877
# 174  2.595255    1.363537  0.908259           3.135494   4.624973
# 175  2.585506    1.453953  0.815365           2.995732   4.787492
# 176  2.577942    0.951658  0.862890           2.995732   4.787492
# 177  2.648300    1.410987  1.007958           3.198673   4.564348
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         1.029619    1.118415             -1.272966         0.828552
# ...

# %%
df.apply(np.log).apply(scale).plot.box();

# %%
fig,axes = plt.subplots(ncols=2, figsize=(18,6))

df.apply(scale).plot.box(ax=axes[0], title = "SEM filtro")
df.apply(np.log).apply(scale).plot.box(ax=axes[1], title = "COM filtro de Transformação Log")

fig.autofmt_xdate(rotation=60, ha='right')

plt.show()

# %% [markdown]
# ##### Box-cox

# %%
df_boxcox = pd.DataFrame(power_transform(df, method='box-cox'), columns=df.columns)
df_boxcox
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.529934   -0.419936  0.209656          -1.180096   1.690664
# 1    0.238692   -0.324973 -0.840423          -2.662695   0.188122
# 2    0.189069    0.313578  1.120488          -0.243599   0.261441
# 3    1.707400   -0.112964  0.471514          -0.799368   1.020309
# 4    0.288354    0.513388  1.906875           0.472325   1.281944
# ..        ...         ...       ...                ...        ...
# 173  0.874837    2.000792  0.284148           0.325346  -0.206825
# 174  0.487399    1.338849  0.396374           1.049814   0.333017
# 175  0.325627    1.507756 -0.412835           0.177260   1.379224
# 176  0.201471    0.513388 -0.012245           0.177260   1.379224
# 177  1.403454    1.428019  1.392956           1.472808  -0.123829
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.820429    1.017090             -0.590039         1.196442
# ...

# %%
fig,axes = plt.subplots(ncols=2, figsize=(18,6))

df.apply(scale).plot.box(ax=axes[0], title = "SEM filtro")
df_boxcox.plot.box(ax=axes[1], title = "COM filtro de Transformação Boxcox")

fig.autofmt_xdate(rotation=60, ha='right')

plt.show()

# %% [markdown]
# ## Tratamento de Datas

# %%
df = pd.read_csv('https://query.data.world/s/2gfb7bmzhna6kcbpc7admwa6cexprz', usecols=['Date','Fatalities']).dropna()
print(df.shape)
df.head()
# Out:
# (5256, 2)
#          Date  Fatalities
# 0  09/17/1908         1.0
# 1  07/12/1912         5.0
# 2  08/06/1913         1.0
# 3  09/09/1913        14.0
# 4  10/17/1913        30.0

# %%
#tipos de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5256 entries, 0 to 5267
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        5256 non-null   object
#  1   Fatalities  5256 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 123.2+ KB

# %% [markdown]
# Forma 1

# %%
pd.to_datetime(df.Date)
# Out:
# 0      1908-09-17
# 1      1912-07-12
# 2      1913-08-06
# 3      1913-09-09
# 4      1913-10-17
#           ...
# 5263   2009-05-20
# 5264   2009-05-26
# 5265   2009-06-01
# 5266   2009-06-07
# 5267   2009-06-08
# Name: Date, Length: 5256, dtype: datetime64[ns]

# %%
pd.to_datetime(df['Date'], format='%m/%d/%Y')
# Out:
# 0      1908-09-17
# 1      1912-07-12
# 2      1913-08-06
# 3      1913-09-09
# 4      1913-10-17
#           ...
# 5263   2009-05-20
# 5264   2009-05-26
# 5265   2009-06-01
# 5266   2009-06-07
# 5267   2009-06-08
# Name: Date, Length: 5256, dtype: datetime64[ns]

# %% [markdown]
# Forma 2

# %%
df['Date'] = df['Date'].astype('datetime64[ns]')

# %%
df['Date']
# Out:
# 0      1908-09-17
# 1      1912-07-12
# 2      1913-08-06
# 3      1913-09-09
# 4      1913-10-17
#           ...
# 5263   2009-05-20
# 5264   2009-05-26
# 5265   2009-06-01
# 5266   2009-06-07
# 5267   2009-06-08
# Name: Date, Length: 5256, dtype: datetime64[ns]

# %% [markdown]
# Forma 3

# %%
df = pd.read_csv('https://query.data.world/s/2gfb7bmzhna6kcbpc7admwa6cexprz', usecols=['Date','Fatalities'], parse_dates=['Date']).dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5256 entries, 0 to 5267
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        5256 non-null   datetime64[ns]
#  1   Fatalities  5256 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 123.2 KB

# %%
df.head()
# Out:
#         Date  Fatalities
# 0 1908-09-17         1.0
# 1 1912-07-12         5.0
# 2 1913-08-06         1.0
# 3 1913-09-09        14.0
# 4 1913-10-17        30.0

# %% [markdown]
# Atributos

# %%
print(list_attributes(df['Date'].dt))
# Out:
# ['as_unit', 'ceil', 'date', 'day', 'day_name', 'day_of_week', 'day_of_year', 'dayofweek', 'dayofyear', 'days_in_month', 'daysinmonth', 'floor', 'freq', 'hour', 'is_leap_year', 'is_month_end', 'is_month_start', 'is_quarter_end', 'is_quarter_start', 'is_year_end', 'is_year_start', 'isocalendar', 'microsecond', 'minute', 'month', 'month_name', 'nanosecond', 'normalize', 'quarter', 'round', 'second', 'strftime', 'time', 'timetz', 'to_period', 'to_pydatetime', 'tz', 'tz_convert', 'tz_localize', 'unit', 'weekday', 'year']

# %%
df['Date'].dt.day
# Out:
# 0       17
# 1       12
# 2        6
# 3        9
# 4       17
#         ..
# 5263    20
# 5264    26
# 5265     1
# 5266     7
# 5267     8
# Name: Date, Length: 5256, dtype: int32

# %%
df['Date'].dt.day_name()
# Out:
# 0        Thursday
# 1          Friday
# 2       Wednesday
# 3         Tuesday
# 4          Friday
#           ...
# 5263    Wednesday
# 5264      Tuesday
# 5265       Monday
# 5266       Sunday
# 5267       Monday
# Name: Date, Length: 5256, dtype: object

# %%
df_index = df.set_index('Date').sort_index()
df_index
# Out:
#             Fatalities
# Date
# 1908-09-17         1.0
# 1912-07-12         5.0
# 1913-08-06         1.0
# 1913-09-09        14.0
# 1913-10-17        30.0
# ...                ...
# 2009-05-20        98.0
# 2009-05-26         4.0
# 2009-06-01       228.0
# 2009-06-07         1.0
# 2009-06-08        13.0
#
# [5256 rows x 1 columns]

# %% [markdown]
# ### Filtrando

# %%
df_index.loc['2000-05': '2003-08']
# Out:
#             Fatalities
# Date
# 2000-05-02         2.0
# 2000-05-03         1.0
# 2000-05-10         6.0
# 2000-05-17         3.0
# 2000-05-21        19.0
# ...                ...
# 2003-08-04         2.0
# 2003-08-08         1.0
# 2003-08-20        20.0
# 2003-08-24        21.0
# 2003-08-26         2.0
#
# [238 rows x 1 columns]

# %%
df_index.resample('ME').sum()
# Out:
#             Fatalities
# Date
# 1908-09-30         1.0
# 1908-10-31         0.0
# 1908-11-30         0.0
# 1908-12-31         0.0
# 1909-01-31         0.0
# ...                ...
# 2009-02-28       102.0
# 2009-03-31        44.0
# 2009-04-30        65.0
# 2009-05-31       120.0
# 2009-06-30       242.0
#
# [1210 rows x 1 columns]

# %%
df_index.resample('MS').sum() #'YS' 'ME'
# Out:
#             Fatalities
# Date
# 1908-09-01         1.0
# 1908-10-01         0.0
# 1908-11-01         0.0
# 1908-12-01         0.0
# 1909-01-01         0.0
# ...                ...
# 2009-02-01       102.0
# 2009-03-01        44.0
# 2009-04-01        65.0
# 2009-05-01       120.0
# 2009-06-01       242.0
#
# [1210 rows x 1 columns]

# %% [markdown]
# ## Rolling Filters

# %%
df = pd.read_csv('https://query.data.world/s/2gfb7bmzhna6kcbpc7admwa6cexprz', usecols=['Date','Fatalities'], parse_dates=['Date'], index_col='Date')
df_monthly = df.resample('ME').sum().sort_index()
df_monthly.head()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_16252\772946772.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly = df.resample('M').sum().sort_index()
#             Fatalities
# Date
# 1908-09-30         1.0
# 1908-10-31         0.0
# 1908-11-30         0.0
# 1908-12-31         0.0
# 1909-01-31         0.0

# %%
plt.figure(figsize=(18,7))
df_monthly.Fatalities.plot();

# %%
df_monthly.Fatalities.rolling(3).mean()
# Out:
# Date
# 1908-09-30           NaN
# 1908-10-31           NaN
# 1908-11-30      0.333333
# 1908-12-31      0.000000
# 1909-01-31      0.000000
#                  ...
# 2009-02-28     42.666667
# 2009-03-31     51.333333
# 2009-04-30     70.333333
# 2009-05-31     76.333333
# 2009-06-30    142.333333
# Freq: ME, Name: Fatalities, Length: 1210, dtype: float64

# %%
# Plot sem tratamento de ruídos com rolling filter
plt.figure(figsize=(18,7))

df_monthly.Fatalities.rolling(12).mean().plot();

# %% [markdown]
# ### Com @interact

# %%
@interact(window_size=(12,121,12))
def rolling_mean(window_size):
  plt.figure(figsize=(18,7))
  df_monthly.Fatalities.rolling(window_size).mean().plot()
  plt.show()
# Out:
# interactive(children=(IntSlider(value=60, description='window_size', max=121, min=12, step=12), Output()), _do…

# %%
rolling_mean(24)
